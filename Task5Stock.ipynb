# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("dataset/Data Set For Task/2) Stock Prices Data Set.csv")
df.head()
# Out:
#   symbol        date      open      high       low     close    volume
# 0    AAL  2014-01-02   25.0700   25.8200   25.0600   25.3600   8998943
# 1   AAPL  2014-01-02   79.3828   79.5756   78.8601   79.0185  58791957
# 2    AAP  2014-01-02  110.3600  111.8800  109.2900  109.7400    542711
# 3   ABBV  2014-01-02   52.1200   52.3300   51.5200   51.9800   4569061
# 4    ABC  2014-01-02   70.1100   70.2300   69.4800   69.8900   1148391

# %%
df["Date"] = pd.to_datetime(df["date"])

# %%
df.columns
# Out:
# Index(['symbol', 'date', 'open', 'high', 'low', 'close', 'volume', 'Date'], dtype='str')

# %%
plt.plot(df["date"], df["close"])
plt.title("Stock Price Trend")
plt.show()

# %%
#TASK 5 STOCK PRICES

# %% [markdown]
# ## Insights
#
# - Stock prices show fluctuating trends over time.
# - Some time periods show consistent upward trends indicating potential growth.
# - Sudden price increases are often followed by short corrections.
# - Time-series visualization helps identify overall market trends.
# - Stock price analysis can assist in better investment decisions.
